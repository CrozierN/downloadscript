# %% [markdown]
# # **All the necessary Imports**
#
# The purpose of this notebook was to download images from a Website for Academic purposes.

# %%
from bs4 import BeautifulSoup

import requests 
import urllib.request
import urllib
import json
import pandas as pd
import time
import unidecode as ud
import os
import pandas as pd

# %% [markdown]
# # **Downloading Script Function**

# %%
def download_imgs(styles, dataset_path, end_range, sub_url):

  image_no = 0
  metadata_imgs = []

  for x in range(1, end_range):
    print(f'Loop: {x}')
    pagination_value = str(x) 
    # Link from XHR Network Tab
    url = sub_url + pagination_value +'&resultType=masonry'

    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    soup_json = json.loads(str(soup))
    dict_json = dict(soup_json)

    painting_info = [paintings for keys, values in dict_json.items() if keys == 'Paintings' for paintings in values]

    for p_index in range(len(painting_info)): #
        img_id = painting_info[p_index]['id']
        title = painting_info[p_index]['title'].replace('"', '')
        year = painting_info[p_index]['year']
        artist_name = painting_info[p_index]['artistName'].replace('"', '')
        link = painting_info[p_index]['image']
        
        scheme, netloc, path, query, fragment = urllib.parse.urlsplit(link)
        path = urllib.parse.quote(path)
        link = urllib.parse.urlunsplit((scheme, netloc, path, query, fragment))
        
        # Convert to utf8 formating 
        decoded_title = ud.unidecode(title).replace("/", "_")
        # title = decoded_title+".jpg"
        title = decoded_title
        
        # Style name 
        image_no = image_no + 1
        img_name = title+'_'+ styles +'_'+ artist_name +'_'+ str(image_no) +'.jpg'
        
        # Save metadata in a json format
        img_metadata = {
            "id" : img_id,
            "title" : title,
            "year" : year,
            "artist_name": artist_name,
            "image" : link,
            "style" : styles,
            "reference_name": img_name
        }
        
        
        full_name = os.path.join(dataset_path, img_name) # Repository to save the imags 


        # Keep track of the images that are downloaded so that there are no duplicates
        if os.path.isfile(full_name):
            print('______________________________________________________________________')
            print(f'{img_name} is already Saved')
            metadata_imgs.append(img_metadata)
            print('______________________________________________________________________')
        else:
            print(f'{img_name} : {decoded_title} to save!')
            urllib.request.urlretrieve(link, full_name)
            metadata_imgs.append(img_metadata)
            print(f'{img_name} : {decoded_title} Saved!')
            print('-------------------------------------')
        
    if x == end_range: 
      print('Downloading done') # indicate if we are done downlading
    
    # Prevent the server from blocking the IP (About 100K Images to be downloaded)
    time.sleep(5)


    return metadata_imgs

# %% [markdown]
# # **Testing using WikiArt API**
#
# Please make note that WikiARt has a dedicted read-only json API.
# For more Information on the API follow this Link: https://www.wikiart.org/en/App/GetApi

# %%
# Dealing with pagination of the website

first_link = 'https://www.wikiart.org/en/paintings-by-style/'
second_link = '?select=featured&json=2&layout=new&page='

# %% [markdown]
# # **Baroque**
#
# Download Baroque Dataset

# %%
styles = 'Baroque' 
dataset_path = '/content/drive/My Drive/Model_Train/Art_Dataset/'

end_range = 5 # This is the number of pages (For the pagination Value)

style_name = 'baroque'
sub_url = first_link + style_name + second_link 

action_dict = download_imgs(styles, dataset_path, end_range, sub_url)
# Out:
# Loop: 1
# St. Agatha, from the episode Holy Women_Baroque_Agostino Carracci_1.jpg : St. Agatha, from the episode Holy Women to save!
# St. Agatha, from the episode Holy Women_Baroque_Agostino Carracci_1.jpg : St. Agatha, from the episode Holy Women Saved!
# -------------------------------------
# St. Catherine, from the episode Holy Women_Baroque_Agostino Carracci_2.jpg : St. Catherine, from the episode Holy Women to save!
# -------------------------------------
# Boy Peeling Fruit_Baroque_Caravaggio_45.jpg : Boy Peeling Fruit to save!
# Boy Peeling Fruit_Baroque_Caravaggio_45.jpg : Boy Peeling Fruit Saved!
# -------------------------------------
# Cardsharps_Baroque_Caravaggio_46.jpg : Cardsharps to save!
# Cardsharps_Baroque_Caravaggio_46.jpg : Cardsharps Saved!
# -------------------------------------
# Musicians_Baroque_Caravaggio_47.jpg : Musicians to save!
# Musicians_Baroque_Caravaggio_47.jpg : Musicians Saved!
# -------------------------------------
# Saint Francis of Assisi in Ecstasy_Baroque_Caravaggio_48.jpg : Saint Francis of Assisi in Ecstasy to save!
# Saint Francis of Assisi in Ecstasy_Baroque_Caravaggio_48.jpg : Saint Francis of Assisi in Ecstasy Saved!
# -------------------------------------
# Adorned by the Graces_Baroque_Annibale Carracci_49.jpg : Adorned by the Graces to save!
# Adorned by the Graces_Baroque_Annibale Carracci_49.jpg : Adorned by the Graces Saved!
# -------------------------------------
# Samson imprisoned_Baroque_Annibale Carracci_50.jpg : Samson imprisoned to save!
# Samson imprisoned_Baroque_Annibale Carracci_50.jpg : Samson imprisoned Saved!
# -------------------------------------
# Sheet of caricatures_Baroque_Annibale Carracci_51.jpg : Sheet of caricatures to save!
# Sheet of caricatures_Baroque_Annibale Carracci_51.jpg : Sheet of caricatures Saved!
# -------------------------------------
# Head of a Faun in a Concave_Baroque_Agostino Carracci_52.jpg : Head of a Faun in a Concave to save!
# Head of a Faun in a Concave_Baroque_Agostino Carracci_52.jpg : Head of a Faun in a Concave Saved!
# -------------------------------------
# Venus Punishing Profane Love_Baroque_Agostino Carracci_53.jpg : Venus Punishing Profane Love to save!
# Venus Punishing Profane Love_Baroque_Agostino Carracci_53.jpg : Venus Punishing Profane Love Saved!
# -------------------------------------
# Landscape with a Marsh_Baroque_Paul Bril_54.jpg : Landscape with a Marsh to save!
# Landscape with a Marsh_Baroque_Paul Bril_54.jpg : Landscape with a Marsh Saved!
# -------------------------------------
# Landscape with Stag Hunt_Baroque_Paul Bril_55.jpg : Landscape with Stag Hunt to save!
# Landscape with Stag Hunt_Baroque_Paul Bril_55.jpg : Landscape with Stag Hunt Saved!
# -------------------------------------
# Landschaft mit Sibyllentempel_Baroque_Paul Bril_56.jpg : Landschaft mit Sibyllentempel to save!
# Landschaft mit Sibyllentempel_Baroque_Paul Bril_56.jpg : Landschaft mit Sibyllentempel Saved!
# -------------------------------------
# The Stag Hunt_Baroque_Paul Bril_57.jpg : The Stag Hunt to save!
# The Stag Hunt_Baroque_Paul Bril_57.jpg : The Stag Hunt Saved!
# -------------------------------------
# Susanna and the Elders_Baroque_Hendrick Goltzius_58.jpg : Susanna and the Elders to save!
# Susanna and the Elders_Baroque_Hendrick Goltzius_58.jpg : Susanna and the Elders Saved!
# -------------------------------------
# Bacchus_Baroque_Caravaggio_59.jpg : Bacchus to save!
# Bacchus_Baroque_Caravaggio_59.jpg : Bacchus Saved!
# -------------------------------------
# Basket of Fruit_Baroque_Caravaggio_60.jpg : Basket of Fruit to save!
# Basket of Fruit_Baroque_Caravaggio_60.jpg : Basket of Fruit Saved!
# -------------------------------------
